# %%
import numpy as np
import pandas as pd

# from mapping import mp

original_data_file = '../datasets/pid.xlsx'
xl = pd.ExcelFile(original_data_file)
print(xl.sheet_names)
# Out:
# ['Quy tắc phân loại', 'T1.2020', '2019', '2018', 'T1-T3.2017', '2016', '2015', '2013', 'Summary']

# %%
mp = {
    "SEA": "SEA",
    "A32431": "SEA",
    "3.7": "A37",
    "A32428": "A37",
    "4.2": "A42",
    "A32426": "A42",
    "THAI": "THAI",
    "A32432": "THAI",
    "FIL": "FIL",
    "HbCS": "HBCS",
    "A32427": "HBCS",
    "HbQs": "HBQS",
    "A32441": "HBQS",
    "2delT": "C2DELT",
    "A32429": "C2DELT",
    
    "-28": "28",
    "cd 27/28": "28",
    "CD28": "28",
    "cd15": "CD15",
    "cd 17": "CD17",
    "CD17": "CD17",
    "A32435": "CD17",
    "Co17": "CD17",
    "cd 19": "CD19",
    "cd 8/9": "CD8.9",
    "cd 26": "CD26",
    "CD26": "CD26",
    "Co26": "CD26",
    "A32433": "CD26",
    "41/42": "CD41.42",
    "A32442": "CD41.42",
    "cd 43": "CD43",
    "71/72": "CD71.72",
    "cd 95": "CD95",
    "CD95": "CD95",
    "cd121": "CD121",
    "IVS": "IVS1.1",
    "A32440": "IVS2.654",
    "89/90": "90",
    "cd90": "90",
    "-88": "88",
    "b-29": "29",
    "b-31": "31"
}

# %%
# df1 = 
# df2 = xl.parse(xl.sheet_names[2])
# df3 = xl.parse(xl.sheet_names[3])
# df4 = xl.parse(xl.sheet_names[4])
# df5 = xl.parse(xl.sheet_names[5])
# df6 = xl.parse(xl.sheet_names[6])
# df7 = xl.parse(xl.sheet_names[7])

df_dict = {
    xl.sheet_names[e]: xl.parse(xl.sheet_names[e]) for e in range(1, 8)
}

# %%
df_dict['T1.2020']

def get_valid_pid(df, names='pid'):
    xn_df = df[['Xét nghi?m', 'PID']]
    pids = []
    
    for i in list(xn_df.index):
        e, pid = xn_df.loc[i].values
        flag = True
        for k in mp.keys():
            if k in str(e):
                pids.append(pid)
                flag = False
                break
        if flag:
            print(e, pid)
    
    pd.DataFrame({'PID': pids}).to_excel(f'{names}.xlsx')
    return pids

# pids = get_valid_pid(df_dict['T1.2020'])
for k, v in df_dict.items():
    get_valid_pid(v, k)
# Out:
# JAK2V617F:ÂM TÍNH 1920081414
# JAK2V617F:ÂM TÍNH 1920081479
# JAK2V617F:ÂM TÍNH 2020106238
# JAK2V617F:ÂM TÍNH 2020106058
# JAK2V617F:ÂM TÍNH 2020106288
# JAK2V617F:DUONG TÍNH 2020106145
# int22:KHÔNG CÓ пO Џ?N 17006460
# JAK2V617F:ÂM TÍNH 2020106393
# JAK2V617F:ÂM TÍNH 2020106364
# JAK2V617F:ÂM TÍNH 2020106336
# JAK2V617F:ÂM TÍNH 1920081577
# JAK2V617F:ÂM TÍNH 1920081584
# JAK2V617F:DUONG TÍNH 2020106355
# JAK2V617F:DUONG TÍNH 1920081572
# int22:Không có d?o do?n 10001865
# JAK2V617F:ÂM TÍNH 2020106510
# JAK2V617F:DUONG TÍNH 2020106337
# JAK2V617F:ÂM TÍNH 1920080992
# JAK2V617F:ÂM TÍNH 2020106527
# JAK2V617F:ÂM TÍNH 2020106616
# JAK2V617F:DUONG TÍNH 2020106536
# JAK2V617F:ÂM TÍNH 2020106856
# JAK2V617F:DUONG TÍNH 2020106597
# JAK2V617F:DUONG TÍNH 2020106852
# JAK2V617F:ÂM TÍNH 2020106910
# int22:KHÔNG CÓ пO Џ?N 07001983
# JAK2V617F:ÂM TÍNH 2020106943
# JAK2V617F:ÂM TÍNH 2020106949
# JAK2V617F:DUONG TÍNH 09022333
# JAK2V617F:ÂM TÍNH 2020106603
# JAK2V617F:DUONG TÍNH 2020106988
# ...

# %%
print(len(pids), df_dict['T1.2020'].shape)
# Out:
# 157 (258, 11)
